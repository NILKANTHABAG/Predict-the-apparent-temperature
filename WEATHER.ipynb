# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('weather_data.csv')

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
df['Formatted Date'].dtypes
# Out:
# dtype('O')

# %%
df['Formatted Date'][0]
# Out:
# '2006-04-01 00:00:00.000 +0200'

# %%
list(df.columns)
# Out:
# ['Formatted Date',
#  'Summary',
#  'Precip Type',
#  'Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Loud Cover',
#  'Pressure (millibars)',
#  'Daily Summary']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   object
#  1   Summary                   5999 non-null   object
#  2   Precip Type               5999 non-null   object
#  3   Temperature (C)           5999 non-null   float64
#  4   Apparent Temperature (C)  5999 non-null   float64
#  5   Humidity                  5999 non-null   float64
#  6   Wind Speed (km/h)         5999 non-null   float64
#  7   Wind Bearing (degrees)    5999 non-null   int64
#  8   Visibility (km)           5999 non-null   float64
#  9   Loud Cover                5999 non-null   int64
#  10  Pressure (millibars)      5999 non-null   float64
#  11  Daily Summary             5999 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
 df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)

# %%
df['Temperature (C)'] = df['Temperature (C)'].astype('int')

# %%
df['Apparent Temperature (C)'] = df['Apparent Temperature (C)'].astype('int')

# %%
df['Humidity'] = df['Humidity'].astype('int')

# %%
df['Wind Speed (km/h)'] = df['Wind Speed (km/h)'].astype('int')

# %%
df['Pressure (millibars)'] = df['Pressure (millibars)'].astype('int')

# %%
# df['Formatted Date'] = df['Formatted Date'].astype('datetime64[ns]')

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   datetime64[ns, UTC]
#  1   Summary                   5999 non-null   object
#  2   Precip Type               5999 non-null   object
#  3   Temperature (C)           5999 non-null   int32
#  4   Apparent Temperature (C)  5999 non-null   int32
#  5   Humidity                  5999 non-null   int32
#  6   Wind Speed (km/h)         5999 non-null   int32
#  7   Wind Bearing (degrees)    5999 non-null   int64
#  8   Visibility (km)           5999 non-null   float64
#  9   Loud Cover                5999 non-null   int64
#  10  Pressure (millibars)      5999 non-null   int32
#  11  Daily Summary             5999 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int32(5), int64(2), object(3)
# ...

# %%
df.shape
# Out:
# (5999, 12)

# %%
df.size
# Out:
# 71988

# %%
df.describe(include='all')
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# count                        5999           5999        5999      5999.000000
# unique                       5999             14           2              NaN
# top     2006-06-18 18:00:00+00:00  Partly Cloudy        rain              NaN
# freq                            1           1791        4762              NaN
# first   2005-12-31 23:00:00+00:00            NaN         NaN              NaN
# last    2006-12-31 22:00:00+00:00            NaN         NaN              NaN
# mean                          NaN            NaN         NaN         9.934656
# std                           NaN            NaN         NaN        10.309955
# min                           NaN            NaN         NaN       -14.000000
# 25%                           NaN            NaN         NaN         1.000000
# 50%                           NaN            NaN         NaN        10.000000
# ...

# %% [markdown]
# # DATA CLEANING

# %%
drpcol=['Summary',
 'Precip Type','Visibility (km)',
 'Loud Cover','Daily Summary','Wind Bearing (degrees)',
]

# %%
df.drop(drpcol,axis=1,inplace=True)
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   datetime64[ns, UTC]
#  1   Temperature (C)           5999 non-null   int32
#  2   Apparent Temperature (C)  5999 non-null   int32
#  3   Humidity                  5999 non-null   int32
#  4   Wind Speed (km/h)         5999 non-null   int32
#  5   Pressure (millibars)      5999 non-null   int32
# dtypes: datetime64[ns, UTC](1), int32(5)
# memory usage: 164.2 KB

# %%
df
# Out:
#                 Formatted Date  Temperature (C)  Apparent Temperature (C)  \
# 0    2006-03-31 22:00:00+00:00                9                         7
# 1    2006-03-31 23:00:00+00:00                9                         7
# 2    2006-04-01 00:00:00+00:00                9                         9
# 3    2006-04-01 01:00:00+00:00                8                         5
# 4    2006-04-01 02:00:00+00:00                8                         6
# ...                        ...              ...                       ...
# 5994 2006-05-15 17:00:00+00:00               19                        19
# 5995 2006-05-15 18:00:00+00:00               17                        17
# 5996 2006-05-15 19:00:00+00:00               15                        15
# 5997 2006-05-15 20:00:00+00:00               13                        13
# 5998 2006-05-15 21:00:00+00:00               12                        12
#
#       Humidity  Wind Speed (km/h)  Pressure (millibars)
# ...

# %%
srt=df.sort_values(by=['Formatted Date'])

# %%
srt.head()
# Out:
#                 Formatted Date  Temperature (C)  Apparent Temperature (C)  \
# 2880 2005-12-31 23:00:00+00:00                0                        -4
# 2881 2006-01-01 00:00:00+00:00                1                        -3
# 2882 2006-01-01 01:00:00+00:00                1                        -3
# 2883 2006-01-01 02:00:00+00:00                1                        -2
# 2884 2006-01-01 03:00:00+00:00                1                        -2
#
#       Humidity  Wind Speed (km/h)  Pressure (millibars)
# 2880         0                 17                  1016
# 2881         0                 16                  1016
# 2882         0                 20                  1015
# 2883         0                 14                  1015
# 2884         0                 13                  1014

# %%
srt = srt.set_index('Formatted Date')
srt.index
# Out:
# DatetimeIndex(['2005-12-31 23:00:00+00:00', '2006-01-01 00:00:00+00:00',
#                '2006-01-01 01:00:00+00:00', '2006-01-01 02:00:00+00:00',
#                '2006-01-01 03:00:00+00:00', '2006-01-01 04:00:00+00:00',
#                '2006-01-01 05:00:00+00:00', '2006-01-01 06:00:00+00:00',
#                '2006-01-01 07:00:00+00:00', '2006-01-01 08:00:00+00:00',
#                ...
#                '2006-12-31 13:00:00+00:00', '2006-12-31 14:00:00+00:00',
#                '2006-12-31 15:00:00+00:00', '2006-12-31 16:00:00+00:00',
#                '2006-12-31 17:00:00+00:00', '2006-12-31 18:00:00+00:00',
#                '2006-12-31 19:00:00+00:00', '2006-12-31 20:00:00+00:00',
#                '2006-12-31 21:00:00+00:00', '2006-12-31 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Formatted Date', length=5999, freq=None)

# %%
srt.index.drop_duplicates(keep='first')
# Out:
# DatetimeIndex(['2005-12-31 23:00:00+00:00', '2006-01-01 00:00:00+00:00',
#                '2006-01-01 01:00:00+00:00', '2006-01-01 02:00:00+00:00',
#                '2006-01-01 03:00:00+00:00', '2006-01-01 04:00:00+00:00',
#                '2006-01-01 05:00:00+00:00', '2006-01-01 06:00:00+00:00',
#                '2006-01-01 07:00:00+00:00', '2006-01-01 08:00:00+00:00',
#                ...
#                '2006-12-31 13:00:00+00:00', '2006-12-31 14:00:00+00:00',
#                '2006-12-31 15:00:00+00:00', '2006-12-31 16:00:00+00:00',
#                '2006-12-31 17:00:00+00:00', '2006-12-31 18:00:00+00:00',
#                '2006-12-31 19:00:00+00:00', '2006-12-31 20:00:00+00:00',
#                '2006-12-31 21:00:00+00:00', '2006-12-31 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Formatted Date', length=5999, freq=None)

# %%
srt.shape
# Out:
# (5999, 5)

# %%
srt.dropna()
srt.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-31 23:00:00+00:00                0                        -4
# 2006-01-01 00:00:00+00:00                1                        -3
# 2006-01-01 01:00:00+00:00                1                        -3
# 2006-01-01 02:00:00+00:00                1                        -2
# 2006-01-01 03:00:00+00:00                1                        -2
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2005-12-31 23:00:00+00:00         0                 17                  1016
# 2006-01-01 00:00:00+00:00         0                 16                  1016
# 2006-01-01 01:00:00+00:00         0                 20                  1015
# 2006-01-01 02:00:00+00:00         0                 14                  1015
# 2006-01-01 03:00:00+00:00         0                 13                  1014

# %%
srt.shape
# Out:
# (5999, 5)

# %%
srt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5999 entries, 2005-12-31 23:00:00+00:00 to 2006-12-31 22:00:00+00:00
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (C)           5999 non-null   int32
#  1   Apparent Temperature (C)  5999 non-null   int32
#  2   Humidity                  5999 non-null   int32
#  3   Wind Speed (km/h)         5999 non-null   int32
#  4   Pressure (millibars)      5999 non-null   int32
# dtypes: int32(5)
# memory usage: 293.1 KB

# %%
srt.describe(include="all")
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      5999.000000               5999.000000  5999.000000
# mean          9.934656                  8.781297     0.025838
# std          10.309955                 11.569563     0.158664
# min         -14.000000                -22.000000     0.000000
# 25%           1.000000                 -1.000000     0.000000
# 50%          10.000000                 10.000000     0.000000
# 75%          18.000000                 18.000000     0.000000
# max          34.000000                 36.000000     1.000000
#
#        Wind Speed (km/h)  Pressure (millibars)
# count        5999.000000           5999.000000
# mean            9.522587            996.878313
# std             6.527760            145.104022
# min             0.000000              0.000000
# 25%             4.000000           1012.000000
# 50%             9.000000           1016.000000
# 75%            13.000000           1022.000000
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
srt.plot(y="Temperature (C)",figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='Formatted Date'>

# %%
srt.index
# Out:
# DatetimeIndex(['2005-12-31 23:00:00+00:00', '2006-01-01 00:00:00+00:00',
#                '2006-01-01 01:00:00+00:00', '2006-01-01 02:00:00+00:00',
#                '2006-01-01 03:00:00+00:00', '2006-01-01 04:00:00+00:00',
#                '2006-01-01 05:00:00+00:00', '2006-01-01 06:00:00+00:00',
#                '2006-01-01 07:00:00+00:00', '2006-01-01 08:00:00+00:00',
#                ...
#                '2006-12-31 13:00:00+00:00', '2006-12-31 14:00:00+00:00',
#                '2006-12-31 15:00:00+00:00', '2006-12-31 16:00:00+00:00',
#                '2006-12-31 17:00:00+00:00', '2006-12-31 18:00:00+00:00',
#                '2006-12-31 19:00:00+00:00', '2006-12-31 20:00:00+00:00',
#                '2006-12-31 21:00:00+00:00', '2006-12-31 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Formatted Date', length=5999, freq=None)

# %%
srt['Formatted Date'] = pd.to_datetime(df['Formatted Date'],utc=True)

# %%
srt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5999 entries, 2005-12-31 23:00:00+00:00 to 2006-12-31 22:00:00+00:00
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (C)           5999 non-null   int32
#  1   Apparent Temperature (C)  5999 non-null   int32
#  2   Humidity                  5999 non-null   int32
#  3   Wind Speed (km/h)         5999 non-null   int32
#  4   Pressure (millibars)      5999 non-null   int32
#  5   Formatted Date            0 non-null      datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int32(5)
# memory usage: 339.9 KB

# %%
#resampling the data into day format
srt1 = srt.resample(rule='D').mean()
srt.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-31 23:00:00+00:00                0                        -4
# 2006-01-01 00:00:00+00:00                1                        -3
# 2006-01-01 01:00:00+00:00                1                        -3
# 2006-01-01 02:00:00+00:00                1                        -2
# 2006-01-01 03:00:00+00:00                1                        -2
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)  \
# Formatted Date
# 2005-12-31 23:00:00+00:00         0                 17                  1016
# 2006-01-01 00:00:00+00:00         0                 16                  1016
# 2006-01-01 01:00:00+00:00         0                 20                  1015
# 2006-01-01 02:00:00+00:00         0                 14                  1015
# 2006-01-01 03:00:00+00:00         0                 13                  1014
#
#                           Formatted Date
# ...

# %%
srt1.plot(y="Temperature (C)",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Formatted Date'>

# %%
jan2006 = srt1['2006-01-01':'2006-01-31']
jan2006
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+00:00         3.500000                 -0.250000
# 2006-01-02 00:00:00+00:00         4.583333                  1.583333
# 2006-01-03 00:00:00+00:00         1.833333                  0.291667
# 2006-01-04 00:00:00+00:00         1.750000                 -0.416667
# 2006-01-05 00:00:00+00:00         2.125000                  0.250000
# 2006-01-06 00:00:00+00:00         2.000000                  0.833333
# 2006-01-07 00:00:00+00:00         0.750000                 -0.500000
# 2006-01-08 00:00:00+00:00        -0.958333                 -2.375000
# 2006-01-09 00:00:00+00:00        -1.541667                 -2.500000
# 2006-01-10 00:00:00+00:00        -0.416667                 -0.583333
# 2006-01-11 00:00:00+00:00        -1.083333                 -1.833333
# 2006-01-12 00:00:00+00:00        -0.166667                 -0.916667
# ...

# %%
jan2006.plot(y=['Apparent Temperature (C)','Temperature (C)'],kind='line',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Formatted Date'>

# %%
JAN = jan2006.resample(rule='D').mean()
JAN.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-01-01 00:00:00+00:00         3.500000                 -0.250000
# 2006-01-02 00:00:00+00:00         4.583333                  1.583333
# 2006-01-03 00:00:00+00:00         1.833333                  0.291667
# 2006-01-04 00:00:00+00:00         1.750000                 -0.416667
# 2006-01-05 00:00:00+00:00         2.125000                  0.250000
#
#                            Humidity  Wind Speed (km/h)  Pressure (millibars)
# Formatted Date
# 2006-01-01 00:00:00+00:00  0.000000          20.625000           1011.541667
# 2006-01-02 00:00:00+00:00  0.000000          17.375000           1009.958333
# 2006-01-03 00:00:00+00:00  0.000000           7.291667           1020.666667
# 2006-01-04 00:00:00+00:00  0.000000          11.666667            981.250000
# 2006-01-05 00:00:00+00:00  0.041667           8.500000            935.458333

# %%
JAN["Temperature (C)"].max()
# Out:
# 4.583333333333333

# %%
# plt.figure(figsize=(2015))
JAN.plot(y=['Temperature (C)','Apparent Temperature (C)'],kind="line",figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Formatted Date'>

# %% [markdown]
# # Correlation in data

# %%
df.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992968 -0.129629
# Apparent Temperature (C)         0.992968                  1.000000 -0.121622
# Humidity                        -0.129629                 -0.121622  1.000000
# Wind Speed (km/h)               -0.058442                 -0.127033 -0.063584
# Pressure (millibars)            -0.080206                 -0.076787 -0.012862
#
#                           Wind Speed (km/h)  Pressure (millibars)
# Temperature (C)                   -0.058442             -0.080206
# Apparent Temperature (C)          -0.127033             -0.076787
# Humidity                          -0.063584             -0.012862
# Wind Speed (km/h)                  1.000000             -0.042306
# Pressure (millibars)              -0.042306              1.000000

# %%
plt.figure(figsize  =(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop(['Temperature (C)'], axis = 1)
# Out:
#                 Formatted Date  Apparent Temperature (C)  Humidity  \
# 0    2006-03-31 22:00:00+00:00                         7         0
# 1    2006-03-31 23:00:00+00:00                         7         0
# 2    2006-04-01 00:00:00+00:00                         9         0
# 3    2006-04-01 01:00:00+00:00                         5         0
# 4    2006-04-01 02:00:00+00:00                         6         0
# ...                        ...                       ...       ...
# 5994 2006-05-15 17:00:00+00:00                        19         0
# 5995 2006-05-15 18:00:00+00:00                        17         0
# 5996 2006-05-15 19:00:00+00:00                        15         0
# 5997 2006-05-15 20:00:00+00:00                        13         0
# 5998 2006-05-15 21:00:00+00:00                        12         0
#
#       Wind Speed (km/h)  Pressure (millibars)
# 0                    14                  1015
# 1                    14                  1015
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize  =(20,20))
sns.pairplot(df)
plt.show()

# %%
sns.distplot(JAN["Temperature (C)"])
# Out:
# <AxesSubplot:xlabel='Temperature (C)', ylabel='Density'>

# %%
sns.distplot(JAN['Apparent Temperature (C)'])
# Out:
# <AxesSubplot:xlabel='Apparent Temperature (C)', ylabel='Density'>

# %%
plt.figure(figsize  =(20,20))
a=sns.barplot('Temperature (C)', 'Humidity',data=JAN)
a.set_xticklabels(a.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, '-11.083333333333334'),
#  Text(1, 0, '-10.375'),
#  Text(2, 0, '-9.333333333333334'),
#  Text(3, 0, '-7.416666666666667'),
#  Text(4, 0, '-6.208333333333333'),
#  Text(5, 0, '-3.2083333333333335'),
#  Text(6, 0, '-3.125'),
#  Text(7, 0, '-2.9583333333333335'),
#  Text(8, 0, '-2.75'),
#  Text(9, 0, '-2.7083333333333335'),
#  Text(10, 0, '-1.7916666666666667'),
#  Text(11, 0, '-1.5416666666666667'),
#  Text(12, 0, '-1.2083333333333333'),
#  Text(13, 0, '-1.0833333333333333'),
#  Text(14, 0, '-0.9583333333333334'),
#  Text(15, 0, '-0.9166666666666666'),
#  Text(16, 0, '-0.8333333333333334'),
#  Text(17, 0, '-0.4166666666666667'),
#  Text(18, 0, '-0.25'),
#  Text(19, 0, '-0.16666666666666666'),
#  Text(20, 0, '-0.041666666666666664'),
#  Text(21, 0, '0.5416666666666666'),
#  Text(22, 0, '0.5833333333333334'),
#  Text(23, 0, '0.75'),
#  Text(24, 0, '1.4583333333333333'),
#  Text(25, 0, '1.75'),
#  Text(26, 0, '1.8333333333333333'),
#  Text(27, 0, '2.0'),
# ...

# %%
sns.jointplot(kind='scatter',y=JAN['Wind Speed (km/h)'],x=JAN['Temperature (C)'],color="blue")

# %%
sns.scatterplot(x='Temperature (C)',y='Humidity',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='Temperature (C)', ylabel='Humidity'>

# %%
plt.figure(figsize  =(20,10))
b=sns.violinplot(x='Temperature (C)',data=JAN,color='green')
b.set_xticklabels(b.get_xticklabels(),rotation = 30)
# Out:
# [Text(-20.0, 0, ''),
#  Text(-15.0, 0, ''),
#  Text(-10.0, 0, ''),
#  Text(-5.0, 0, ''),
#  Text(0.0, 0, ''),
#  Text(5.0, 0, ''),
#  Text(10.0, 0, '')]

# %%
plt.figure(figsize  =(20,10))
b=sns.violinplot(x='Apparent Temperature (C)',data=JAN,color="yellow")
b.set_xticklabels(a.get_xticklabels(),rotation = 30)
# Out:
# [Text(-25.0, 0, '-11.083333333333334'),
#  Text(-20.0, 0, '-10.375'),
#  Text(-15.0, 0, '-9.333333333333334'),
#  Text(-10.0, 0, '-7.416666666666667'),
#  Text(-5.0, 0, '-6.208333333333333'),
#  Text(0.0, 0, '-3.2083333333333335'),
#  Text(5.0, 0, '-3.125'),
#  Text(10.0, 0, '-2.9583333333333335')]

# %% [markdown]
# # PREDICTING APPERANT TEMPERATURE

# %%
target=df['Apparent Temperature (C)']
data = df.loc[:,['Temperature (C)', 'Humidity',
       'Wind Speed (km/h)', 'Pressure (millibars)']]

# %%
target.head()
# Out:
# 0    7
# 1    7
# 2    9
# 3    5
# 4    6
# Name: Apparent Temperature (C), dtype: int32

# %%
data.head()
# Out:
#    Temperature (C)  Humidity  Wind Speed (km/h)  Pressure (millibars)
# 0                9         0                 14                  1015
# 1                9         0                 14                  1015
# 2                9         0                  3                  1015
# 3                8         0                 14                  1016
# 4                8         0                 11                  1016

# %%
JAN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2006-01-01 00:00:00+00:00 to 2006-01-31 00:00:00+00:00
# Freq: D
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (C)           31 non-null     float64
#  1   Apparent Temperature (C)  31 non-null     float64
#  2   Humidity                  31 non-null     float64
#  3   Wind Speed (km/h)         31 non-null     float64
#  4   Pressure (millibars)      31 non-null     float64
# dtypes: float64(5)
# memory usage: 2.5 KB

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler().fit_transform(data)
print(standardized_data.shape)
# Out:
# (5999, 4)

# %%
# Data-preprocessing: Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(standardized_data, \
                                                   target, \
                                                   test_size = 0.25, \
                                                   random_state = 0)

# %%
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier.fit(X_train, y_train)

# %%
# y_pred = classifier.predict(X_test)

# %%
# # calculate accuracy of class predictions
# from sklearn import metrics
# metrics.accuracy_score(y_test, y_pred)

# %% [markdown]
# # linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[-1.06068045, -0.16285862,  0.22634656,  0.30409471],
#        [ 0.68535057, -0.16285862,  1.1455746 ,  0.09043706],
#        [ 1.17035918, -0.16285862, -0.08006279, -6.87066696],
#        ...,
#        [-1.06068045, -0.16285862, -0.99929083,  0.22138852],
#        [-0.47867011, -0.16285862,  1.1455746 ,  0.1111136 ],
#        [-1.15768218, -0.16285862, -0.84608615,  0.1524667 ]])

# %%
X_train=pd.DataFrame(X_train)

# %%
X_train.shape
# Out:
# (4499, 4)

# %%
X_train.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(y_train)
# Out:
# 1824    -5
# 253     17
# 1114    22
# 3220     1
# 2108     4
#         ..
# 4931    25
# 3264   -17
# 1653    -1
# 2607     1
# 2732    -4
# Name: Apparent Temperature (C), Length: 4499, dtype: int32

# %%
print(regressor .coef_)
print(regressor .intercept_)
# Out:
# [11.45753393  0.04233428 -0.80647235 -0.0217543 ]
# 8.775859025994928

# %%
plt.scatter(X_train[0], y_train)

plt.plot(X_train[0], 8.775859025994928+ 11.45753393* X_train[0], 'r')

plt.show()

# %%
y_pred = regressor.predict(X_test)

# %%
regressor.score(X_test,y_test)
# Out:
# 0.9907847211566567

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#       Actual  Predicted
# 4320      21  21.005290
# 2006       0  -0.359630
# 5688       5   4.829857
# 472       21  21.747222
# 1370      15  15.326229
# ...      ...        ...
# 3362      -8 -10.362987
# 2846      -4  -2.333521
# 1712      -2  -1.348073
# 4227      16  16.559386
# 1806      -1  -0.855953
#
# [1500 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  0.8806468690922158
# Mean Squared Error:  1.2622368775330812
# Root Mean Squared Error:  1.1234931586498786

# %%
print(X_train.index)
# Out:
# RangeIndex(start=0, stop=4499, step=1)

# %%
#Taking input from user for prediction

# %%
xinput=[[21,20,5,6]]

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler()
standardized_data.fit_transform(data)
# Out:
# array([[-0.09066322, -0.16285862,  0.68596058,  0.12489797],
#        [-0.09066322, -0.16285862,  0.68596058,  0.12489797],
#        [-0.09066322, -0.16285862, -0.99929083,  0.12489797],
#        ...,
#        [ 0.49134712, -0.16285862, -1.30570017,  0.15935888],
#        [ 0.29734367, -0.16285862, -0.99929083,  0.16625106],
#        [ 0.20034195, -0.16285862, -1.1524955 ,  0.16625106]])

# %%
z=standardized_data.transform(xinput)

# %%
own_pred=regressor.predict(z)
print("predicted score={}".format(own_pred))
# Out:
# predicted score=[27.11113973]

# %% [markdown]
# #                                            <center>END</center>
